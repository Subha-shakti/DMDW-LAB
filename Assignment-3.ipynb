# %% [markdown]
# <a href="https://colab.research.google.com/github/Subha-shakti/DMDW-LAB/blob/main/Assignment-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Book1.csv')

# %%
print(df)
# Out:
#    roll name  age gen   branch sec
# 0     1    a   23   m      cse   b
# 1     2    b   23   m      cse   b
# 2     3    c   43   m       ds   c
# 3     4    d   12   m  cseaiml   d
# 4     5    e   23   f       cv   c
# 5     6    f   21   m      mca   d
# 6     7    g   19   f      bca   d
# 7     8    h   18   m      cse   a
# 8     9    i   19   f      cse   a
# 9    10    j   20   f       cv   a

# %%
print(df.head())
# Out:
#    roll name  age gen   branch sec
# 0     1    a   23   m      cse   b
# 1     2    b   23   m      cse   b
# 2     3    c   43   m       ds   c
# 3     4    d   12   m  cseaiml   d
# 4     5    e   23   f       cv   c

# %%
print(df.tail())
# Out:
#    roll name  age gen branch sec
# 5     6    f   21   m    mca   d
# 6     7    g   19   f    bca   d
# 7     8    h   18   m    cse   a
# 8     9    i   19   f    cse   a
# 9    10    j   20   f     cv   a

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   age     10 non-null     int64
#  3   gen     10 non-null     object
#  4   branch  10 non-null     object
#  5   sec     10 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 612.0+ bytes
# None

# %%
df.describe()
# Out:
#            roll        age
# count  10.00000  10.000000
# mean    5.50000  22.100000
# std     3.02765   8.047774
# min     1.00000  12.000000
# 25%     3.25000  19.000000
# 50%     5.50000  20.500000
# 75%     7.75000  23.000000
# max    10.00000  43.000000

# %%
df.shape
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'age', 'gen', 'branch', 'sec'], dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.isnull()
# Out:
#     roll   name    age    gen  branch    sec
# 0  False  False  False  False   False  False
# 1  False  False  False  False   False  False
# 2  False  False  False  False   False  False
# 3  False  False  False  False   False  False
# 4  False  False  False  False   False  False
# 5  False  False  False  False   False  False
# 6  False  False  False  False   False  False
# 7  False  False  False  False   False  False
# 8  False  False  False  False   False  False
# 9  False  False  False  False   False  False

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# age        int64
# gen       object
# branch    object
# sec       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# roll      0
# name      0
# age       0
# gen       0
# branch    0
# sec       0
# dtype: int64

# %%
df.iloc[0]
# Out:
# roll        1
# name        a
# age        23
# gen         m
# branch    cse
# sec         b
# Name: 0, dtype: object

# %%
df.loc(1)

# %%
ages=df['age']
print(ages)
# Out:
# 0    23
# 1    23
# 2    43
# 3    12
# 4    23
# 5    21
# 6    19
# 7    18
# 8    19
# 9    20
# Name: age, dtype: int64

# %%
male=df['gen']

# %%
adults = df[(df['age'] > 19) & (df['age'] < 20)]
print("Those whose age is between 19 and 20:\n", adults)
# Out:
# Those whose age is between 19 and 20:
#  Empty DataFrame
# Columns: [roll, name, age, gen, branch, sec]
# Index: []

# %%
males = df[df['gen'] == 'm']

print("Male candidates:\n", males)
# Out:
# Male candidates:
#     roll name  age gen   branch sec
# 0     1    a   23   m      cse   b
# 1     2    b   23   m      cse   b
# 2     3    c   43   m       ds   c
# 3     4    d   12   m  cseaiml   d
# 5     6    f   21   m      mca   d
# 7     8    h   18   m      cse   a

# %%
df.sort_values(by='age', ascending=True)
# Out:
#    roll name  age gen   branch sec
# 3     4    d   12   m  cseaiml   d
# 7     8    h   18   m      cse   a
# 6     7    g   19   f      bca   d
# 8     9    i   19   f      cse   a
# 9    10    j   20   f       cv   a
# 5     6    f   21   m      mca   d
# 0     1    a   23   m      cse   b
# 1     2    b   23   m      cse   b
# 4     5    e   23   f       cv   c
# 2     3    c   43   m       ds   c
